# %%
import numpy as np
from dataset_config import DatasetConfig
from dataset_builder import (build_final_dataset, sanity_check, save_dataset)
config = DatasetConfig(n_total_core=8000)
dataset = build_final_dataset(config)
sanity_check(dataset)
save_dataset(dataset, 'dataset')
# Out:
# Salvato: dataset_arrays.npz, dataset_meta.pkl
